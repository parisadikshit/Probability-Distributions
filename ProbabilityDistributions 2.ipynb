# %% [markdown]
# # Probability Distributions and plots using Python

# %%
#importing all necessary python modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#setting seaborn styles
sns.set(color_codes=True)

# %%
#setting plot size
sns.set(rc={'figure.figsize':(5,5)})

# %%
#reading csv- marks of 60 students out of 50
data = pd.read_csv('fictional_marks.csv')

# %%
#first five rows of the dataset
data.head()
# Out:
#     Students  Total Marks Response for Extra Class
# 0   Priyanka           20                       No
# 1     Shreya           21                       No
# 2    Rawknee           24                       No
# 3  Vaishnavi           45                      Yes
# 4       Amit           34                       No

# %%
#relational plot of students' marks and claiming the response eg.student with marks 25 doesn't want extra class
#by default scatterplot
ax = sns.relplot(x='Response for Extra Class',y='Total Marks',data=data)

# %%
#line plot 
ax = sns.relplot(x='Response for Extra Class',y='Total Marks',data=data,kind='line')

# %%
#column marks - array
marks = data['Total Marks']

# %%
# a histogram 
ax = sns.distplot(
    marks,
    hist=True,
    bins=50,
    color='skyblue',
    hist_kws={'linewidth':20,'alpha':1}
)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Another Dataset Analysis

# %%
Data_2 = pd.read_csv('fictional_studentinfo.csv')

# %%
Data_2.head()
# Out:
#        Name     Sex  Marks                School Favourite Subject  \
# 0  Yashwant    Male     45   Sharada High School             Maths
# 1   Vinayak    Male     45   Sadhana High School           Science
# 2     Shree    Male     34  Karmveer High School           Science
# 3    Shreya  Female     34   Sadhana High School           Science
# 4   Kalpana  Female     23   Sadhana High School             Maths
#
#   Do you like Cricket? Tea/Coffee/Other IV response
# 0                  Yes              Tea          No
# 1                  Yes              Tea         Yes
# 2                   No           Coffee         Yes
# 3                  Yes            Other         Yes
# 4                   No            Other         Yes

# %% [markdown]
# # Probability Distributions

# %% [markdown]
# # By using sns.displot():

# %% [markdown]
# # Uniform Distribution:

# %%
#importing uniform function from scipy stats
from scipy.stats import uniform

# %%
# generating uniform distributed random numbers starting from 10 with scale of 20 and size 1000
n=1000
start=10
width=20
data_uniform = uniform.rvs(size=n,loc=start,scale=width)

# %%
ax= sns.displot(
    data_uniform,
    bins=100,
    kde=True,
    color='skyblue'
)
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')

# %% [markdown]
# # Normal Distribution:

# %%
#importing normal function from scipy stats
from scipy.stats import norm

# %%
#generating normal distributed random variables;loc,scale being mean and standard deviation respectively
data_normal = norm.rvs(size=1000,loc=0,scale=1)

# %%
ax= sns.displot(
    data_normal,
    bins=100,
    kde=True,
    color='skyblue'
)
ax.set(xlabel='Normal Distribution',ylabel='Frequency')

# %% [markdown]
# # Poisson Distribution:

# %%
#importing poisson function from scipy stats
from scipy.stats import poisson

# %%
#generating poisson distributed random varibales 
data_poisson = poisson.rvs(mu=6,size=1000)

# %%
ax= sns.displot(
    data_poisson,
    bins=100,
    kde=False,
    color='skyblue',
)
ax.set(xlabel='Poisson Distribution',ylabel='Frequency')

# %% [markdown]
# # By using sns.distplot():

# %% [markdown]
# # Poisson Distribution:

# %%
ax= sns.distplot(
    data_poisson,
    bins=100,
    kde=False,
    color='skyblue',
    hist_kws={'linewidth':15,'alpha':1}
)
ax.set(xlabel='Poisson Distribution',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]

# %% [markdown]
# # Normal Distribution:

# %%
ax= sns.distplot(
    data_normal,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={"linewidth":20,"alpha":1}
)
ax.set(xlabel='Normal Distribution',ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %% [markdown]
# # Uniform Distribution:

# %%
ax = sns.distplot(
    data_uniform,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={'linewidth':20,'alpha':1}
)
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Uniform Distribution')]

# %% [markdown]
# # Bernoulli Distribution
